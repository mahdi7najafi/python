# %%
import os
import requests

# %%
#url = 'https://api.lib.harvard.edu/v2/items?title=MARC 21'
url = 'https://api.lib.harvard.edu/v2/collections?limit=100' 
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'created': '2018-11-15T20:46:41',
#   'modified': '2020-05-13T14:57:24',
#   'baseUrl': 'https://id.lib.harvard.edu/curiosity/crime-broadsides/46-',
#   'collectionUrn': 'http://nrs.harvard.edu/urn-3:hul.eresource:dyingspe',
#   'contactDepartment': 'Historical and Special Collections, Harvard Law Library',
#   'contactName': 'Karen Beck',
#   'dcp': True,
#   'systemId': 1,
#   'public': True,
#   'setDescription': 'This collection of nearly 600 broadsides highlights crime and capital punishment, primarily in England, as seen through the popular press in the 18th and 19th century.',
#   'setName': 'English Crime and Execution Broadsides',
#   'setSpec': 'crimes',
#   'thumbnailUrn': 'http://nrs.harvard.edu/urn-3:HLS.Libr:912568?n=178'},
#  {'created': '2018-11-15T21:05:56',
#   'modified': '2020-05-12T16:49:44',
#   'baseUrl': 'https://id.lib.harvard.edu/curiosity/studies-in-scarlet/41-',
#   'collectionUrn': 'http://nrs.harvard.edu/urn-3:hul.eresource:sscarlet',
# ...

# %%
r = response.json()

# %%
import json
import pandas as pd
df = pd.read_json(json.dumps(r))
df
# Out:
#                 created            modified  \
# 0   2018-11-15T20:46:41 2020-05-13 14:57:24
# 1   2018-11-15T21:05:56 2020-05-12 16:49:44
# 2   2018-11-15T21:13:08 2019-08-07 14:23:41
# 3   2018-11-15T21:33:02 2019-07-02 10:00:58
# 4   2018-11-15T22:55:06 2019-08-07 12:21:40
# 5   2018-11-16T10:06:38 2019-02-28 15:39:10
# 6   2018-11-16T11:44:18 2019-08-07 21:45:42
# 7   2018-11-16T12:01:26 2020-05-13 16:56:17
# 8   2018-11-28T14:16:35 2020-05-19 15:03:11
# 9   2018-11-28T14:27:04 2020-05-18 17:57:58
# 10  2018-11-28T16:50:12 2020-05-19 12:47:14
# 11  2018-11-29T12:04:20 2020-03-04 16:36:43
# 12  2018-11-29T12:12:08 2020-03-04 17:08:44
# 13  2018-11-29T13:26:40 2021-04-14 10:34:21
# 14  2018-12-04T14:36:54 2019-02-26 20:03:39
# 15  2018-12-04T15:07:46 2019-02-26 20:07:34
# 16  2018-12-04T15:45:27 2019-02-26 20:16:29
# 17  2019-01-28T14:43:47 2020-07-13 11:28:44
# 18  2019-01-28T22:38:57 2020-05-22 11:52:12
# 19  2019-05-22T14:03:36 2020-05-19 16:30:11
# ...
